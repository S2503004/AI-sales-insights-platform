# %% [markdown]
# # Sales Insights Demo Notebook\nDemonstrates ETL, training and prediction with the provided API.

# %%
import requests\nprint('Use the FastAPI endpoints after starting the server.')
